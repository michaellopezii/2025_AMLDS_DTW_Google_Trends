# %%
import pandas as pd
import os
from datetime import datetime
from collections import Counter

# %%
def get_time_period(date_str):
    # Categorize date into specific time periods

    date = datetime.strptime(date_str, '%Y-%m-%d')
    if datetime(2020, 4, 1) <= date <= datetime(2020, 6, 30):
        return 'April-June 2020'
    elif datetime(2020, 7, 1) <= date <= datetime(2020, 9, 30):
        return 'July-September 2020'
    elif datetime(2020, 10, 1) <= date <= datetime(2020, 12, 31):
        return 'October-December 2020'
    elif datetime(2021, 1, 1) <= date <= datetime(2021, 3, 31):
        return 'January-March 2021'
    return 'Other'

def analyze_connections(adj_matrix):
    # Analyze pairwise keyword connections

    keywords = list(adj_matrix.columns[1:])  # Skip 'Unnamed: 0'
    connections = []
    
    # Look at lower triangular part only
    for i in range(1, len(keywords)):
        for j in range(i):
            if adj_matrix.iloc[i, j+1] == 1:  # +1 because first column is index
                connections.append(tuple(sorted([keywords[i], keywords[j]])))
    
    return connections

def find_triads(adj_matrix):
    # Find triads (triangles) in the network
    
    keywords = list(adj_matrix.columns[1:])  # Skip 'Unnamed: 0'
    triads = []
    
    # Look for triangles in lower triangular part
    for i in range(2, len(keywords)):
        for j in range(1, i):
            for k in range(j):
                if (adj_matrix.iloc[i, j+1] == 1 and 
                    adj_matrix.iloc[i, k+1] == 1 and 
                    adj_matrix.iloc[j, k+1] == 1):
                    triads.append(tuple(sorted([keywords[i], keywords[j], keywords[k]])))
    
    return triads

# %%
def process_network_files(base_dir, window_size, threshold):
    # Process all files for a given window size and threshold
    
    threshold_dir = os.path.join(base_dir, f"{threshold}_threshold")
    
    # Initialize counters for each time period
    period_connections = {
        'April-June 2020': Counter(),
        'July-September 2020': Counter(),
        'October-December 2020': Counter(),
        'January-March 2021': Counter()
    }
    period_triads = {
        'April-June 2020': Counter(),
        'July-September 2020': Counter(),
        'October-December 2020': Counter(),
        'January-March 2021': Counter()
    }
    
    # Process each file
    for file in sorted(os.listdir(threshold_dir)):
        if file.endswith('.csv'):
            # Extract date from filename
            date_parts = file.split('_')[-3:]
            date_str = f"{date_parts[0]}-{date_parts[1]}-{date_parts[2].replace('.csv', '')}"
            period = get_time_period(date_str)
            
            if period in period_connections:
                # Read and process matrix
                filepath = os.path.join(threshold_dir, file)
                adj_matrix = pd.read_csv(filepath)
                
                # Analyze connections and triads
                connections = analyze_connections(adj_matrix)
                triads = find_triads(adj_matrix)
                
                # Update counters
                period_connections[period].update(connections)
                period_triads[period].update(triads)
    
    return period_connections, period_triads

# %%
def print_results(period_connections, period_triads, window_size, threshold):
    # Print analysis results in organized format

    print(f"\n{'='*80}")
    print(f"Results for {window_size}-day window, threshold {threshold}")
    print(f"{'='*80}")
    
    for period in period_connections.keys():
        if period_connections[period] or period_triads[period]:  # Only print if there are results
            print(f"\n{period}")
            print("-" * len(period))
            
            print("\nMost Common Keyword Pairs:")
            for pair, count in period_connections[period].most_common(10):  # Top 10 pairs
                print(f"{pair[0]} - {pair[1]}: {count} connections")
            
            print("\nMost Common Triads:")
            for triad, count in period_triads[period].most_common(10):  # Top 10 triads
                print(f"{triad[0]} - {triad[1]} - {triad[2]}: {count} occurrences")
            
            print("\n" + "-"*40)

# %%
def process_network_files(base_dir, window_size, threshold):
    # Process all files for a given window size and threshold
    
    threshold_dir = os.path.join(base_dir, f"{threshold}_threshold")
    
    # Initialize counters for each time period
    period_connections = {
        'April-June 2020': Counter(),
        'July-September 2020': Counter(),
        'October-December 2020': Counter(),
        'January-March 2021': Counter()
    }
    period_triads = {
        'April-June 2020': Counter(),
        'July-September 2020': Counter(),
        'October-December 2020': Counter(),
        'January-March 2021': Counter()
    }
    
    # Process each file
    for file in sorted(os.listdir(threshold_dir)):
        if file.endswith('.csv'):
            # Extract date from filename
            date_parts = file.split('_')[-3:]
            date_str = f"{date_parts[0]}-{date_parts[1]}-{date_parts[2].replace('.csv', '')}"
            period = get_time_period(date_str)
            
            if period in period_connections:
                # Read and process matrix
                filepath = os.path.join(threshold_dir, file)
                adj_matrix = pd.read_csv(filepath)
                
                # Analyze connections and triads
                connections = analyze_connections(adj_matrix)
                triads = find_triads(adj_matrix)
                
                # Update counters
                period_connections[period].update(connections)
                period_triads[period].update(triads)
    
    return period_connections, period_triads

# %%
# Define directories and thresholds
rsv_dirs = [
    "../gt_corr_adj_matrix/gt_adj_matrices_rsv_normal_15day",
    "../gt_corr_adj_matrix/gt_adj_matrices_rsv_normal_30day"
]
thresholds = [0.4, 0.5, 0.6, 0.8]

# Run analysis for each directory and threshold
for rsv_dir in rsv_dirs:
    window_size = '15' if '15day' in rsv_dir else '30'
    
    for threshold in thresholds:
        period_connections, period_triads = process_network_files(rsv_dir, window_size, threshold)
        print_results(period_connections, period_triads, window_size, threshold)
# Out:
# ================================================================================
# Results for 15-day window, threshold 0.4
# ================================================================================
#
# April-June 2020
# ---------------
#
# Most Common Keyword Pairs:
# Quarantine - ecq: 85 connections
# social distancing - work from home: 82 connections
# fever - headache: 81 connections
# fever - flu: 80 connections
# cough - fever: 80 connections
# flu - rashes: 78 connections
# ecq - masks: 78 connections
# Frontliners - fever: 75 connections
# fever - social distancing: 74 connections
# ecq - flu: 73 connections
#
# Most Common Triads:
# Frontliners - social distancing - work from home: 60 occurrences
# cough - ecq - fever: 57 occurrences
# ecq - flu - rashes: 56 occurrences
# Frontliners - cough - flu: 56 occurrences
# Frontliners - fever - flu: 56 occurrences
# cough - fever - flu: 55 occurrences
# ecq - fever - flu: 55 occurrences
# cough - ecq - flu: 54 occurrences
# ecq - fever - masks: 54 occurrences
# cough - flu - rashes: 54 occurrences
#
# ----------------------------------------
#
# July-September 2020
# -------------------
#
# Most Common Keyword Pairs:
# Quarantine - ecq: 92 connections
# rashes - work from home: 78 connections
# Quarantine - face shield: 78 connections
# cough - ecq: 76 connections
# face shield - flu: 75 connections
# fever - flu: 74 connections
# ecq - face shield: 72 connections
# ecq - rashes: 72 connections
# headache - masks: 72 connections
# masks - sipon: 70 connections
#
# Most Common Triads:
# Quarantine - ecq - face shield: 68 occurrences
# Quarantine - ecq - flu: 58 occurrences
# Quarantine - ecq - rashes: 58 occurrences
# Quarantine - ecq - masks: 55 occurrences
# Quarantine - cough - ecq: 52 occurrences
# Quarantine - ecq - fever: 52 occurrences
# cough - face shield - flu: 51 occurrences
# ecq - rashes - work from home: 50 occurrences
# Quarantine - cough - face shield: 49 occurrences
# Quarantine - face shield - fever: 49 occurrences
#
# ----------------------------------------
#
# October-December 2020
# ---------------------
#
# Most Common Keyword Pairs:
# rashes - sipon: 83 connections
# headache - work from home: 72 connections
# rashes - work from home: 72 connections
# fever - sipon: 71 connections
# Frontliners - face shield: 71 connections
# Frontliners - social distancing: 70 connections
# Frontliners - sipon: 68 connections
# flu - work from home: 68 connections
# Frontliners - ecq: 67 connections
# Quarantine - face shield: 66 connections
#
# Most Common Triads:
# fever - rashes - sipon: 50 occurrences
# Frontliners - rashes - sipon: 44 occurrences
# ecq - rashes - work from home: 44 occurrences
# Quarantine - face shield - rashes: 42 occurrences
# rashes - sipon - work from home: 40 occurrences
# Quarantine - rashes - sipon: 40 occurrences
# flu - rashes - work from home: 38 occurrences
# Frontliners - face shield - sipon: 38 occurrences
# flu - headache - work from home: 37 occurrences
# Frontliners - headache - work from home: 36 occurrences
#
# ----------------------------------------
#
# January-March 2021
# ------------------
#
# Most Common Keyword Pairs:
# headache - sipon: 70 connections
# Frontliners - fever: 60 connections
# cough - fever: 59 connections
# cough - ubo: 59 connections
# fever - ubo: 56 connections
# sipon - ubo: 56 connections
# masks - ubo: 54 connections
# flu - work from home: 54 connections
# Quarantine - rashes: 53 connections
# flu - rashes: 51 connections
#
# Most Common Triads:
# cough - sipon - ubo: 36 occurrences
# face shield - headache - sipon: 35 occurrences
# cough - fever - ubo: 33 occurrences
# Quarantine - cough - fever: 29 occurrences
# cough - headache - sipon: 28 occurrences
# headache - sipon - ubo: 27 occurrences
# Frontliners - cough - fever: 27 occurrences
# rashes - sipon - ubo: 26 occurrences
# Quarantine - face shield - sipon: 26 occurrences
# Quarantine - headache - rashes: 25 occurrences
#
# ----------------------------------------
#
# ================================================================================
# Results for 15-day window, threshold 0.5
# ================================================================================
#
# April-June 2020
# ---------------
#
# Most Common Keyword Pairs:
# Quarantine - ecq: 72 connections
# social distancing - work from home: 65 connections
# ecq - flu: 58 connections
# Frontliners - fever: 57 connections
# fever - flu: 56 connections
# Frontliners - work from home: 56 connections
# cough - ecq: 53 connections
# cough - fever: 51 connections
# ecq - fever: 51 connections
# fever - social distancing: 51 connections
#
# Most Common Triads:
# cough - ecq - flu: 38 occurrences
# cough - ecq - fever: 38 occurrences
# cough - fever - flu: 36 occurrences
# Frontliners - cough - flu: 35 occurrences
# ecq - fever - flu: 34 occurrences
# Frontliners - fever - flu: 33 occurrences
# cough - flu - social distancing: 33 occurrences
# cough - fever - social distancing: 33 occurrences
# fever - flu - social distancing: 31 occurrences
# Frontliners - cough - fever: 30 occurrences
#
# ----------------------------------------
#
# July-September 2020
# -------------------
#
# Most Common Keyword Pairs:
# Quarantine - ecq: 92 connections
# Quarantine - face shield: 62 connections
# fever - flu: 55 connections
# ecq - face shield: 51 connections
# face shield - flu: 51 connections
# Quarantine - flu: 50 connections
# ecq - flu: 46 connections
# face shield - fever: 44 connections
# face shield - masks: 40 connections
# Frontliners - masks: 40 connections
#
# Most Common Triads:
# Quarantine - ecq - face shield: 47 occurrences
# Quarantine - ecq - flu: 39 occurrences
# face shield - fever - flu: 36 occurrences
# Quarantine - fever - flu: 29 occurrences
# Frontliners - Quarantine - ecq: 28 occurrences
# ecq - face shield - flu: 26 occurrences
# Quarantine - face shield - fever: 26 occurrences
# ecq - face shield - fever: 25 occurrences
# Quarantine - face shield - flu: 25 occurrences
# Quarantine - ecq - fever: 23 occurrences
#
# ----------------------------------------
#
# October-December 2020
# ---------------------
#
# Most Common Keyword Pairs:
# rashes - sipon: 56 connections
# flu - work from home: 48 connections
# ecq - work from home: 40 connections
# Frontliners - ecq: 38 connections
# Frontliners - face shield: 38 connections
# headache - work from home: 37 connections
# lagnat - ubo: 34 connections
# face shield - rashes: 33 connections
# Frontliners - headache: 33 connections
# Quarantine - cough: 33 connections
#
# Most Common Triads:
# Frontliners - rashes - sipon: 13 occurrences
# Frontliners - ecq - ubo: 11 occurrences
# fever - rashes - sipon: 10 occurrences
# masks - sipon - ubo: 10 occurrences
# Frontliners - face shield - sipon: 9 occurrences
# flu - rashes - work from home: 9 occurrences
# lagnat - rashes - ubo: 9 occurrences
# lagnat - masks - ubo: 8 occurrences
# Frontliners - ecq - headache: 8 occurrences
# flu - headache - work from home: 8 occurrences
#
# ----------------------------------------
#
# January-March 2021
# ------------------
#
# Most Common Keyword Pairs:
# sipon - ubo: 40 connections
# fever - lagnat: 33 connections
# cough - fever: 31 connections
# rashes - ubo: 31 connections
# Frontliners - fever: 31 connections
# rashes - social distancing: 27 connections
# masks - work from home: 27 connections
# ecq - lagnat: 26 connections
# Quarantine - fever: 25 connections
# flu - rashes: 24 connections
#
# Most Common Triads:
# Quarantine - ecq - rashes: 11 occurrences
# face shield - masks - work from home: 10 occurrences
# cough - fever - rashes: 9 occurrences
# fever - headache - lagnat: 8 occurrences
# ecq - flu - lagnat: 8 occurrences
# ecq - rashes - social distancing: 6 occurrences
# Quarantine - rashes - social distancing: 6 occurrences
# Quarantine - ecq - social distancing: 6 occurrences
# sipon - ubo - work from home: 6 occurrences
# flu - rashes - ubo: 6 occurrences
#
# ----------------------------------------
#
# ================================================================================
# Results for 15-day window, threshold 0.6
# ================================================================================
#
# April-June 2020
# ---------------
#
# Most Common Keyword Pairs:
# Quarantine - ecq: 61 connections
# social distancing - work from home: 46 connections
# cough - ecq: 43 connections
# ecq - flu: 42 connections
# fever - flu: 38 connections
# cough - flu: 37 connections
# cough - fever: 36 connections
# ecq - fever: 35 connections
# Frontliners - flu: 34 connections
# fever - social distancing: 33 connections
#
# Most Common Triads:
# cough - fever - flu: 33 occurrences
# cough - ecq - fever: 31 occurrences
# cough - ecq - flu: 27 occurrences
# ecq - fever - flu: 27 occurrences
# Frontliners - cough - flu: 27 occurrences
# Frontliners - flu - social distancing: 26 occurrences
# fever - flu - social distancing: 25 occurrences
# cough - flu - social distancing: 25 occurrences
# cough - fever - social distancing: 24 occurrences
# Frontliners - cough - social distancing: 24 occurrences
#
# ----------------------------------------
#
# July-September 2020
# -------------------
#
# Most Common Keyword Pairs:
# Quarantine - ecq: 86 connections
# Quarantine - face shield: 38 connections
# face shield - fever: 36 connections
# Quarantine - flu: 34 connections
# face shield - flu: 34 connections
# ecq - face shield: 33 connections
# fever - flu: 31 connections
# Frontliners - Quarantine: 26 connections
# Frontliners - ecq: 25 connections
# ecq - flu: 24 connections
#
# Most Common Triads:
# Quarantine - ecq - face shield: 24 occurrences
# face shield - fever - flu: 24 occurrences
# Frontliners - Quarantine - ecq: 20 occurrences
# Quarantine - ecq - flu: 16 occurrences
# ecq - face shield - flu: 16 occurrences
# Quarantine - face shield - flu: 14 occurrences
# face shield - fever - rashes: 13 occurrences
# face shield - flu - rashes: 13 occurrences
# flu - rashes - social distancing: 13 occurrences
# Quarantine - face shield - fever: 12 occurrences
#
# ----------------------------------------
#
# October-December 2020
# ---------------------
#
# Most Common Keyword Pairs:
# flu - work from home: 28 connections
# Frontliners - ecq: 25 connections
# rashes - sipon: 21 connections
# ecq - ubo: 16 connections
# headache - work from home: 16 connections
# Frontliners - headache: 13 connections
# masks - sipon: 13 connections
# flu - rashes: 12 connections
# ecq - work from home: 12 connections
# Frontliners - Quarantine: 12 connections
#
# Most Common Triads:
# Frontliners - face shield - masks: 4 occurrences
# lagnat - rashes - work from home: 4 occurrences
# Frontliners - Quarantine - social distancing: 3 occurrences
# Frontliners - ecq - ubo: 2 occurrences
# flu - headache - work from home: 2 occurrences
# Frontliners - face shield - rashes: 2 occurrences
# flu - headache - social distancing: 1 occurrences
# Frontliners - headache - work from home: 1 occurrences
# Frontliners - flu - work from home: 1 occurrences
# masks - sipon - ubo: 1 occurrences
#
# ----------------------------------------
#
# January-March 2021
# ------------------
#
# Most Common Keyword Pairs:
# ecq - lagnat: 24 connections
# sipon - ubo: 22 connections
# fever - lagnat: 16 connections
# Quarantine - rashes: 13 connections
# Quarantine - ecq: 13 connections
# face shield - work from home: 11 connections
# rashes - social distancing: 10 connections
# face shield - masks: 10 connections
# masks - work from home: 10 connections
# cough - fever: 10 connections
#
# Most Common Triads:
# face shield - masks - work from home: 4 occurrences
# Frontliners - ecq - lagnat: 4 occurrences
# Quarantine - rashes - social distancing: 3 occurrences
# Quarantine - face shield - rashes: 2 occurrences
# cough - fever - lagnat: 2 occurrences
# cough - ecq - fever: 2 occurrences
# cough - ecq - lagnat: 2 occurrences
# ecq - fever - lagnat: 2 occurrences
# Quarantine - ecq - headache: 1 occurrences
# Quarantine - ecq - rashes: 1 occurrences
#
# ----------------------------------------
#
# ================================================================================
# Results for 15-day window, threshold 0.8
# ================================================================================
#
# April-June 2020
# ---------------
#
# Most Common Keyword Pairs:
# fever - flu: 29 connections
# cough - flu: 29 connections
# cough - fever: 27 connections
# Quarantine - ecq: 24 connections
# ecq - fever: 16 connections
# Frontliners - flu: 9 connections
# Frontliners - Quarantine: 9 connections
# ecq - flu: 8 connections
# cough - ecq: 8 connections
# Frontliners - ecq: 8 connections
#
# Most Common Triads:
# cough - fever - flu: 26 occurrences
# ecq - fever - flu: 8 occurrences
# Frontliners - fever - flu: 6 occurrences
# Frontliners - ecq - fever: 6 occurrences
# cough - ecq - fever: 6 occurrences
# Frontliners - ecq - flu: 5 occurrences
# cough - ecq - flu: 5 occurrences
# Frontliners - cough - flu: 4 occurrences
# Quarantine - cough - flu: 3 occurrences
# Quarantine - fever - flu: 3 occurrences
#
# ----------------------------------------
#
# July-September 2020
# -------------------
#
# Most Common Keyword Pairs:
# Quarantine - ecq: 52 connections
# Quarantine - face shield: 13 connections
# Frontliners - ecq: 10 connections
# face shield - flu: 10 connections
# ecq - face shield: 8 connections
# fever - flu: 7 connections
# face shield - fever: 6 connections
# Quarantine - flu: 5 connections
# Frontliners - Quarantine: 4 connections
# cough - flu: 4 connections
#
# Most Common Triads:
# Frontliners - Quarantine - ecq: 4 occurrences
# Quarantine - face shield - flu: 3 occurrences
# face shield - fever - flu: 1 occurrences
# Quarantine - face shield - fever: 1 occurrences
# Quarantine - ecq - face shield: 1 occurrences
#
# ----------------------------------------
#
# October-December 2020
# ---------------------
#
# Most Common Keyword Pairs:
# Frontliners - masks: 4 connections
# Frontliners - ecq: 3 connections
# Quarantine - ecq: 3 connections
# ecq - ubo: 2 connections
# Frontliners - sipon: 1 connections
# lagnat - social distancing: 1 connections
# Frontliners - headache: 1 connections
# sipon - ubo: 1 connections
# lagnat - rashes: 1 connections
#
# Most Common Triads:
#
# ----------------------------------------
#
# January-March 2021
# ------------------
#
# Most Common Keyword Pairs:
# ecq - lagnat: 16 connections
# cough - fever: 6 connections
# Quarantine - ecq: 5 connections
# ecq - fever: 2 connections
# headache - lagnat: 1 connections
# Quarantine - flu: 1 connections
# cough - lagnat: 1 connections
#
# Most Common Triads:
#
# ----------------------------------------
#
# ================================================================================
# Results for 30-day window, threshold 0.4
# ================================================================================
#
# April-June 2020
# ---------------
#
# Most Common Keyword Pairs:
# social distancing - work from home: 76 connections
# ecq - flu: 74 connections
# Quarantine - ecq: 74 connections
# Frontliners - Quarantine: 67 connections
# cough - fever: 65 connections
# Frontliners - fever: 55 connections
# Frontliners - ecq: 53 connections
# cough - ecq: 51 connections
# ecq - fever: 48 connections
# Frontliners - flu: 48 connections
#
# Most Common Triads:
# cough - ecq - fever: 44 occurrences
# Frontliners - Quarantine - ecq: 44 occurrences
# cough - ecq - flu: 43 occurrences
# Frontliners - cough - fever: 41 occurrences
# cough - fever - flu: 40 occurrences
# ecq - fever - flu: 40 occurrences
# cough - fever - social distancing: 40 occurrences
# Frontliners - cough - flu: 38 occurrences
# Frontliners - fever - flu: 38 occurrences
# Frontliners - Quarantine - social distancing: 38 occurrences
#
# ----------------------------------------
#
# July-September 2020
# -------------------
#
# Most Common Keyword Pairs:
# Quarantine - ecq: 92 connections
# fever - headache: 78 connections
# fever - flu: 77 connections
# face shield - fever: 71 connections
# face shield - flu: 65 connections
# cough - flu: 63 connections
# cough - fever: 60 connections
# cough - face shield: 60 connections
# Frontliners - face shield: 50 connections
# Quarantine - flu: 47 connections
#
# Most Common Triads:
# face shield - fever - flu: 51 occurrences
# cough - face shield - flu: 47 occurrences
# cough - fever - flu: 46 occurrences
# cough - face shield - fever: 43 occurrences
# ecq - face shield - fever: 37 occurrences
# cough - fever - headache: 36 occurrences
# cough - face shield - sipon: 33 occurrences
# Frontliners - Quarantine - ecq: 33 occurrences
# ecq - fever - flu: 31 occurrences
# Quarantine - cough - ecq: 29 occurrences
#
# ----------------------------------------
#
# October-December 2020
# ---------------------
#
# Most Common Keyword Pairs:
# Frontliners - ecq: 58 connections
# headache - work from home: 47 connections
# Frontliners - Quarantine: 44 connections
# Frontliners - social distancing: 43 connections
# flu - work from home: 40 connections
# Quarantine - ecq: 39 connections
# rashes - social distancing: 39 connections
# Frontliners - headache: 39 connections
# rashes - sipon: 38 connections
# face shield - rashes: 38 connections
#
# Most Common Triads:
# face shield - fever - flu: 17 occurrences
# Quarantine - fever - flu: 17 occurrences
# Quarantine - face shield - flu: 17 occurrences
# Quarantine - face shield - fever: 17 occurrences
# Frontliners - rashes - sipon: 16 occurrences
# Frontliners - Quarantine - ecq: 14 occurrences
# fever - flu - rashes: 12 occurrences
# face shield - flu - rashes: 12 occurrences
# face shield - fever - rashes: 12 occurrences
# Quarantine - ecq - face shield: 12 occurrences
#
# ----------------------------------------
#
# January-March 2021
# ------------------
#
# Most Common Keyword Pairs:
# Frontliners - fever: 41 connections
# cough - fever: 39 connections
# Quarantine - ecq: 37 connections
# sipon - ubo: 31 connections
# Frontliners - work from home: 28 connections
# Quarantine - fever: 27 connections
# flu - work from home: 27 connections
# Quarantine - rashes: 26 connections
# fever - lagnat: 24 connections
# Frontliners - cough: 23 connections
#
# Most Common Triads:
# Quarantine - ecq - rashes: 20 occurrences
# Quarantine - cough - fever: 17 occurrences
# Frontliners - cough - fever: 6 occurrences
# cough - fever - rashes: 5 occurrences
# Quarantine - ecq - headache: 4 occurrences
# Quarantine - fever - headache: 4 occurrences
# cough - fever - sipon: 3 occurrences
# Quarantine - flu - work from home: 3 occurrences
# Frontliners - social distancing - work from home: 2 occurrences
# Quarantine - cough - headache: 2 occurrences
#
# ----------------------------------------
#
# ================================================================================
# Results for 30-day window, threshold 0.5
# ================================================================================
#
# April-June 2020
# ---------------
#
# Most Common Keyword Pairs:
# social distancing - work from home: 61 connections
# Quarantine - ecq: 57 connections
# ecq - flu: 46 connections
# cough - fever: 42 connections
# cough - ecq: 42 connections
# Frontliners - Quarantine: 42 connections
# Frontliners - flu: 38 connections
# ecq - fever: 36 connections
# Frontliners - fever: 36 connections
# cough - flu: 35 connections
#
# Most Common Triads:
# cough - fever - flu: 34 occurrences
# cough - ecq - fever: 34 occurrences
# cough - ecq - flu: 32 occurrences
# ecq - fever - flu: 32 occurrences
# Frontliners - fever - flu: 30 occurrences
# Frontliners - cough - fever: 28 occurrences
# Frontliners - cough - flu: 27 occurrences
# Quarantine - social distancing - work from home: 19 occurrences
# cough - flu - social distancing: 18 occurrences
# fever - flu - social distancing: 18 occurrences
#
# ----------------------------------------
#
# July-September 2020
# -------------------
#
# Most Common Keyword Pairs:
# Quarantine - ecq: 90 connections
# fever - flu: 63 connections
# cough - face shield: 50 connections
# face shield - flu: 44 connections
# cough - fever: 42 connections
# face shield - fever: 42 connections
# fever - headache: 39 connections
# cough - flu: 37 connections
# cough - ecq: 31 connections
# Frontliners - Quarantine: 31 connections
#
# Most Common Triads:
# cough - face shield - flu: 28 occurrences
# Frontliners - Quarantine - ecq: 27 occurrences
# face shield - fever - flu: 26 occurrences
# ecq - face shield - fever: 22 occurrences
# ecq - fever - flu: 19 occurrences
# ecq - face shield - flu: 19 occurrences
# Quarantine - ecq - face shield: 18 occurrences
# cough - ecq - face shield: 17 occurrences
# Quarantine - face shield - flu: 17 occurrences
# Quarantine - face shield - fever: 16 occurrences
#
# ----------------------------------------
#
# October-December 2020
# ---------------------
#
# Most Common Keyword Pairs:
# Frontliners - ecq: 40 connections
# Frontliners - headache: 22 connections
# Frontliners - Quarantine: 21 connections
# rashes - sipon: 19 connections
# headache - work from home: 18 connections
# face shield - fever: 17 connections
# flu - work from home: 15 connections
# Quarantine - face shield: 14 connections
# Quarantine - ecq: 13 connections
# face shield - flu: 13 connections
#
# Most Common Triads:
# Quarantine - face shield - fever: 4 occurrences
# Frontliners - face shield - sipon: 4 occurrences
# Quarantine - ecq - fever: 3 occurrences
# flu - rashes - social distancing: 3 occurrences
# Frontliners - ecq - social distancing: 3 occurrences
# face shield - flu - rashes: 2 occurrences
# Quarantine - face shield - flu: 2 occurrences
# Frontliners - headache - social distancing: 1 occurrences
#
# ----------------------------------------
#
# January-March 2021
# ------------------
#
# Most Common Keyword Pairs:
# Quarantine - ecq: 27 connections
# Quarantine - rashes: 25 connections
# cough - fever: 22 connections
# sipon - ubo: 19 connections
# ecq - lagnat: 17 connections
# Frontliners - fever: 12 connections
# fever - lagnat: 10 connections
# Frontliners - work from home: 9 connections
# Quarantine - fever: 8 connections
# Frontliners - cough: 5 connections
#
# Most Common Triads:
# Quarantine - cough - fever: 4 occurrences
# Frontliners - cough - fever: 3 occurrences
#
# ----------------------------------------
#
# ================================================================================
# Results for 30-day window, threshold 0.6
# ================================================================================
#
# April-June 2020
# ---------------
#
# Most Common Keyword Pairs:
# social distancing - work from home: 39 connections
# Quarantine - ecq: 38 connections
# cough - ecq: 35 connections
# cough - flu: 34 connections
# fever - flu: 34 connections
# cough - fever: 34 connections
# ecq - fever: 32 connections
# ecq - flu: 27 connections
# Frontliners - cough: 27 connections
# Frontliners - flu: 24 connections
#
# Most Common Triads:
# cough - fever - flu: 34 occurrences
# cough - ecq - fever: 32 occurrences
# cough - ecq - flu: 26 occurrences
# ecq - fever - flu: 26 occurrences
# Frontliners - cough - flu: 22 occurrences
# Frontliners - fever - flu: 17 occurrences
# Frontliners - cough - fever: 16 occurrences
# Quarantine - cough - flu: 10 occurrences
# Quarantine - fever - flu: 9 occurrences
# Quarantine - cough - fever: 9 occurrences
#
# ----------------------------------------
#
# July-September 2020
# -------------------
#
# Most Common Keyword Pairs:
# Quarantine - ecq: 82 connections
# fever - flu: 31 connections
# face shield - flu: 28 connections
# Frontliners - ecq: 27 connections
# cough - face shield: 26 connections
# cough - fever: 24 connections
# face shield - fever: 23 connections
# cough - flu: 23 connections
# Frontliners - Quarantine: 22 connections
# cough - headache: 20 connections
#
# Most Common Triads:
# Frontliners - Quarantine - ecq: 22 occurrences
# face shield - fever - flu: 20 occurrences
# ecq - face shield - flu: 15 occurrences
# cough - fever - headache: 8 occurrences
# ecq - face shield - fever: 8 occurrences
# cough - face shield - flu: 7 occurrences
# ecq - fever - flu: 7 occurrences
# Quarantine - ecq - face shield: 7 occurrences
# Quarantine - face shield - flu: 6 occurrences
# Quarantine - face shield - fever: 6 occurrences
#
# ----------------------------------------
#
# October-December 2020
# ---------------------
#
# Most Common Keyword Pairs:
# Frontliners - headache: 5 connections
# Quarantine - flu: 3 connections
# Frontliners - ecq: 3 connections
# Frontliners - Quarantine: 2 connections
# Quarantine - ecq: 2 connections
# Quarantine - face shield: 1 connections
# ecq - ubo: 1 connections
# flu - work from home: 1 connections
# face shield - sipon: 1 connections
# rashes - sipon: 1 connections
#
# Most Common Triads:
#
# ----------------------------------------
#
# January-March 2021
# ------------------
#
# Most Common Keyword Pairs:
# Quarantine - ecq: 21 connections
# ecq - lagnat: 13 connections
# cough - fever: 4 connections
# sipon - ubo: 3 connections
# Quarantine - fever: 2 connections
# fever - lagnat: 1 connections
# Frontliners - fever: 1 connections
#
# Most Common Triads:
#
# ----------------------------------------
#
# ================================================================================
# Results for 30-day window, threshold 0.8
# ================================================================================
#
# April-June 2020
# ---------------
#
# Most Common Keyword Pairs:
# cough - flu: 32 connections
# fever - flu: 32 connections
# cough - fever: 32 connections
# ecq - fever: 15 connections
# ecq - flu: 5 connections
# Quarantine - ecq: 5 connections
# cough - ecq: 4 connections
# fever - social distancing: 4 connections
# flu - social distancing: 3 connections
# Quarantine - flu: 2 connections
#
# Most Common Triads:
# cough - fever - flu: 32 occurrences
# ecq - fever - flu: 5 occurrences
# cough - ecq - fever: 4 occurrences
# fever - flu - social distancing: 3 occurrences
# cough - ecq - flu: 3 occurrences
# Quarantine - flu - social distancing: 2 occurrences
# cough - flu - social distancing: 2 occurrences
# cough - fever - social distancing: 2 occurrences
# Quarantine - fever - flu: 1 occurrences
# Quarantine - fever - social distancing: 1 occurrences
#
# ----------------------------------------
#
# July-September 2020
# -------------------
#
# Most Common Keyword Pairs:
# Quarantine - ecq: 50 connections
# face shield - flu: 10 connections
# cough - flu: 6 connections
# ecq - face shield: 5 connections
# cough - fever: 2 connections
# Frontliners - ecq: 2 connections
# Quarantine - face shield: 2 connections
#
# Most Common Triads:
#
# ----------------------------------------
